# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import warnings
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

warnings.filterwarnings('ignore')

# %%
# Import StatsBomb classes - safe to run multiple times
try:
    from src.utils.config import StatsBombConfig
    from src.utils.data_fetcher import StatsBombDataFetcher
    print("✓ Imports successful")
except ImportError as e:
    print(f"✗ Import error: {e}")
    print("Make sure you're running this from the notebooks directory")
# Out:
# ✓ Imports successful

# %%
# Initialize StatsBomb classes - safe to run multiple times
try:
    config = StatsBombConfig()
    fetcher = StatsBombDataFetcher()
    print("✓ StatsBomb classes initialized successfully")
except Exception as e:
    print(f"✗ Initialization error: {e}")
    print("Check your .env file for STATSBOMB_USERNAME and STATSBOMB_PASSWORD")
# Out:
# Usuario configurado: itam_hackathon@hudl.com
# Usuario configurado: itam_hackathon@hudl.com
# ✓ StatsBomb classes initialized successfully

# %%
competitions = fetcher.get_competitions()
# Out:
# Obteniendo competiciones...
# 4 competiciones obtenidas

# %%
competitions
# Out:
#    competition_id  season_id country_name competition_name competition_gender  \
# 0              73        317       Mexico          Liga MX               male
# 1              73        281       Mexico          Liga MX               male
# 2              73        235       Mexico          Liga MX               male
# 3              73        108       Mexico          Liga MX               male
#
#    competition_youth  competition_international season_name  \
# 0              False                      False   2024/2025
# 1              False                      False   2023/2024
# 2              False                      False   2022/2023
# 3              False                      False   2021/2022
#
#                 match_updated           match_updated_360  \
# 0  2025-08-30T16:14:20.970616  2025-08-30T16:14:20.970616
# 1  2024-12-20T23:40:31.103974  2024-12-20T23:40:31.103974
# 2  2024-09-28T11:05:11.667984  2024-09-28T11:05:11.667984
# ...

# %%
matches_2122 = fetcher.get_matches(73, 108)
matches_2122[matches_2122['home_team'] == 'Juárez'].head(3)
# Out:
# Obteniendo partidos (Comp: 73, Temp: 108)...
# 342 partidos obtenidos
#     match_id  match_date      kick_off       competition     season home_team  \
# 0    3799426  2021-09-22  02:00:00.000  Mexico - Liga MX  2021/2022    Juárez
# 6    3799484  2021-08-14  02:00:00.000  Mexico - Liga MX  2021/2022    Juárez
# 23   3816698  2022-04-03  03:00:00.000  Mexico - Liga MX  2021/2022    Juárez
#
#             away_team  home_score  away_score attendance  ...  \
# 0   Atlético San Luis           1           0       None  ...
# 6             Tijuana           1           1       None  ...
# 23         Pumas UNAM           0           1       None  ...
#
#               last_updated_360  match_week competition_stage  \
# 0   2021-09-26T17:44:43.113256          14          Apertura
# 6   2021-08-19T15:03:45.487000           4          Apertura
# 23  2022-04-07T12:29:01.045387          12          Clausura
#
#                                            stadium  \
# ...

# %%
matches_2223 = fetcher.get_matches(73,235)
# Out:
# Obteniendo partidos (Comp: 73, Temp: 235)...
# 342 partidos obtenidos

# %%
lineup_prueba = fetcher.get_lineups(3799426)
lineup_prueba
# Out:
# Obteniendo alineaciones del partido 3799426...
# Alineaciones obtenidas para 2 equipos
# {'Atlético San Luis':     player_id                         player_name       player_nickname  \
#  0       26289                 Javier Güemez López         Javier Güemez
#  1       26306       Adam Fernando Bareiro Gamarra          Adam Bareiro
#  2       26331                    Marcelo Barovero                  None
#  3       27083              Jhon Fredy Duque Arias            Jhon Duque
#  4       27967                  Unai Bilbao Arteta           Unai Bilbao
#  5       28056              Juan David Castro Ruiz           Juan Castro
#  6       28160                 Ricardo Chávez Soto        Ricardo Chávez
#  7       28515                Emmanuel García Vaca       Emmanuel García
#  8       28560           Jair Alberto Díaz Vázquez             Jair Díaz
#  9       28764                    Germán Berterame                  None
# ...

# %%
events_prueba_1 = fetcher.get_events(3799426,True)
# Out:
# Obteniendo eventos del partido 3799426...
# 3053 eventos obtenidos

# %%
events_prueba_2 = fetcher.get_events(3799460,True)
events_prueba_2['type'].unique()
# Out:
# Obteniendo eventos del partido 3799460...
# 3347 eventos obtenidos
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt*', 'Carry',
#        'Pressure', 'Ball Recovery', 'Block', 'Foul Committed', 'Foul Won',
#        'Interception', 'Clearance', 'Dispossessed', 'Duel',
#        'Own Goal Against', 'Own Goal For', 'Shield', 'Miscontrol', 'Shot',
#        'Goal Keeper', 'Dribble', 'Dribbled Past', '50/50',
#        'Injury Stoppage', 'Half End', 'Substitution', 'Tactical Shift',
#        'Referee Ball-Drop'], dtype=object)

# %%
c21 = fetcher.get_player_match_stats(3799426)
c21.head(3)
# Out:
# Obteniendo estadísticas de jugadores del partido 3799426...
# Estadísticas de 30 jugadores obtenidas
#    account_id  match_id  team_id          team_name  player_id  \
# 0       41100   3799426     1291             Juárez      28167
# 1       41100   3799426     1291             Juárez      28499
# 2       41100   3799426     1287  Atlético San Luis      26331
#
#         player_name  player_match_minutes  player_match_np_xg_per_shot  \
# 0   Fabián Castillo             76.350000                          NaN
# 1              Caco             99.083336                          NaN
# 2  Marcelo Barovero             99.083336                          NaN
#
#    player_match_np_xg  player_match_np_shots  ...  player_match_claim_success  \
# 0                 0.0                      0  ...                         NaN
# 1                 0.0                      0  ...                         NaN
# 2                 0.0                      0  ...                         NaN
#
# ...

# %%
#all columns in c21
c21.columns
# Out:
# Index(['account_id', 'match_id', 'team_id', 'team_name', 'player_id',
#        'player_name', 'player_match_minutes', 'player_match_np_xg_per_shot',
#        'player_match_np_xg', 'player_match_np_shots',
#        ...
#        'player_match_claim_success', 'player_match_da_aggressive_distance',
#        'player_match_goals_conceded', 'player_match_gsaa',
#        'player_match_gk_positioning_error',
#        'player_match_positive_outcome_score', 'player_match_npot_psxg_faced',
#        'player_match_save_ratio', 'player_match_gsaa_ratio',
#        'player_match_npot_shots_faced'],
#       dtype='object', length=167)

# %%
jug_juarez = c21[c21['team_name'] == 'Juárez']
jug_juarez.head(3)
# Out:
#    account_id  match_id  team_id team_name  player_id      player_name  \
# 0       41100   3799426     1291    Juárez      28167  Fabián Castillo
# 1       41100   3799426     1291    Juárez      28499             Caco
# 3       41100   3799426     1291    Juárez      26303    Hugo González
#
#    player_match_minutes  player_match_np_xg_per_shot  player_match_np_xg  \
# 0             76.350000                          NaN                 0.0
# 1             99.083336                          NaN                 0.0
# 3             99.083336                          NaN                 0.0
#
#    player_match_np_shots  ...  player_match_claim_success  \
# 0                      0  ...                         NaN
# 1                      0  ...                         NaN
# 3                      0  ...                         1.0
#
#    player_match_da_aggressive_distance  player_match_goals_conceded  \
# 0                            69.726929                            0
# ...

# %%
stats_jugadores_21 = fetcher.get_player_season_stats(73,108)
stats_jugadores_21
# Out:
# Obteniendo estadísticas de los jugadores para (Comp: 73, Temp: 108)...
# Estadísticas de 603 jugadores obtenidas
#      account_id  player_id                  player_name  team_id  \
# 0         41100      12254              Alessio da Cruz     1299
# 1         41100      26272     Ventura Alvarado Aispuro     1291
# 2         41100      30458  Alejandro Zendejas Saavedra     1221
# 3         41100      28529   Fernando David Arce Juárez     1221
# 4         41100      30458  Alejandro Zendejas Saavedra     1229
# ..          ...        ...                          ...      ...
# 598       41100      27967           Unai Bilbao Arteta     1287
# 599       41100      23722              Pol García Tena     1291
# 600       41100      27970           Ian González Nieto     1227
# 601       41100      47467     Álvaro Fidalgo Fernández     1229
# 602       41100       8818             Jorge Meré Pérez     1229
#
#              team_name  competition_id competition_name  season_id  \
# ...

# %%
for i in stats_jugadores_21.columns.unique():
    print(i)
# Out:
# account_id
# player_id
# player_name
# team_id
# team_name
# competition_id
# competition_name
# season_id
# season_name
# country_id
# birth_date
# player_female
# player_first_name
# player_last_name
# player_known_name
# player_weight
# player_height
# player_season_minutes
# player_season_np_xg_per_shot
# player_season_np_xg_90
# player_season_np_shots_90
# player_season_goals_90
# player_season_npga_90
# player_season_xa_90
# player_season_key_passes_90
# player_season_op_key_passes_90
# player_season_assists_90
# player_season_through_balls_90
# player_season_passes_into_box_90
# player_season_op_passes_into_box_90
# player_season_touches_inside_box_90
# player_season_op_passes_into_and_touches_inside_box_90
# player_season_tackles_90
# player_season_interceptions_90
# player_season_tackles_and_interceptions_90
# player_season_padj_tackles_90
# player_season_padj_interceptions_90
# player_season_padj_tackles_and_interceptions_90
# player_season_challenge_ratio
# ...
